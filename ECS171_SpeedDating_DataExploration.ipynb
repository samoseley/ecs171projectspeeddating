# %% [markdown]
# # Data/Environment Setup

# %%
import pandas as pd
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/samoseley/ecs171projectspeeddating/main/Speed%20Dating%20Data.csv'
df = pd.read_csv(url, encoding='latin1')

# %%
df.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4  ...
# 1    1  1.0       0    1       1     1     10         7       NaN      3  ...
# 2    1  1.0       0    1       1     1     10         7       NaN     10  ...
# 3    1  1.0       0    1       1     1     10         7       NaN      5  ...
# 4    1  1.0       0    1       1     1     10         7       NaN      7  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  \
# 0      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 1      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 2      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 3      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 4      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
#
#    fun5_3  amb5_3
# 0     NaN     NaN
# ...

# %% [markdown]
# ##Basic Information

# %%
df.shape
# Out:
# (8378, 195)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8378 entries, 0 to 8377
# Columns: 195 entries, iid to amb5_3
# dtypes: float64(174), int64(13), object(8)
# memory usage: 12.5+ MB

# %%
df.columns.values

#definitions: indvi = person taking survey, partner = person partnered with survey taker

#wave, round, position, order all seem to refer to how speed dating was set up
#gender = gender of indivi
#match = yes/no (is it a match) our target
#int_corr = how much interests correlate
#samerace = same race
#age_o = age of partner (_o seems to indicate the partner)
#race_o = race of partner
#pf_o_att = how important partner rates attactiveness
#categories: sin = sincerity, int = inteligence, fun = funny, amb = ambition, sha = shared interests, 
#dec_o = decion of partner on night of event
#attr_o = how partner rates indvi attractiveness (follows through for other categories)
#like_o = how partner likes indvi
#prob_o = patner met indvi before
#met_o = partner met indvi before
#age = age of indvi
#field = field of study of indvi
#undergra, mn_sat, tuituion = something with school
#race = race of indvi
#imprace = importance of same race
#imprelig = importance of religion
#from, zipcode, = where indvi is from
#income, goal, date, go_out, career, carrer_c = stuff about indvi
#ports, tvsports ... yoga = indvi interests
#exphappy = how happy indvi expects to be with a person met during speed dating
#expnum = how many partners do you expect to be interested in you or how many matches you expect to get
#attr1_1, sinc1_1, intel1_1... seem to be ratings of your partner (numbers seem to have to do with the set up of the speed dating)
#attr, sinc, intel ... indvi rating their own attractiveness/sincerity etc.
# Out:
# array(['iid', 'id', 'gender', 'idg', 'condtn', 'wave', 'round',
#        'position', 'positin1', 'order', 'partner', 'pid', 'match',
#        'int_corr', 'samerace', 'age_o', 'race_o', 'pf_o_att', 'pf_o_sin',
#        'pf_o_int', 'pf_o_fun', 'pf_o_amb', 'pf_o_sha', 'dec_o', 'attr_o',
#        'sinc_o', 'intel_o', 'fun_o', 'amb_o', 'shar_o', 'like_o',
#        'prob_o', 'met_o', 'age', 'field', 'field_cd', 'undergra',
#        'mn_sat', 'tuition', 'race', 'imprace', 'imprelig', 'from',
#        'zipcode', 'income', 'goal', 'date', 'go_out', 'career',
#        'career_c', 'sports', 'tvsports', 'exercise', 'dining', 'museums',
#        'art', 'hiking', 'gaming', 'clubbing', 'reading', 'tv', 'theater',
#        'movies', 'concerts', 'music', 'shopping', 'yoga', 'exphappy',
#        'expnum', 'attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1',
#        'shar1_1', 'attr4_1', 'sinc4_1', 'intel4_1', 'fun4_1', 'amb4_1',
# ...

# %%
df.describe()
# Out:
#                iid           id       gender          idg       condtn  \
# count  8378.000000  8377.000000  8378.000000  8378.000000  8378.000000
# mean    283.675937     8.960248     0.500597    17.327166     1.828837
# std     158.583367     5.491329     0.500029    10.940735     0.376673
# min       1.000000     1.000000     0.000000     1.000000     1.000000
# 25%     154.000000     4.000000     0.000000     8.000000     2.000000
# 50%     281.000000     8.000000     1.000000    16.000000     2.000000
# 75%     407.000000    13.000000     1.000000    26.000000     2.000000
# max     552.000000    22.000000     1.000000    44.000000     2.000000
#
#               wave        round     position     positin1        order  ...  \
# count  8378.000000  8378.000000  8378.000000  6532.000000  8378.000000  ...
# mean     11.350919    16.872046     9.042731     9.295775     8.927668  ...
# std       5.995903     4.358458     5.514939     5.650199     5.477009  ...
# ...

# %% [markdown]
# # Speed Dating Data Exploration

# %% [markdown]
# important cols:
# * percieved interest
# * sharedinterestso
# * sharedinterestpartner
# * attractive
# * sincere
# * intelligence
# * funny
# * ambition

# %% [markdown]
# ##Correlation Matrix

# %%
from matplotlib import rcParams

# figure size in inches
rcParams['figure.figsize'] = 15,15

corr = df.drop(columns = ['iid', 'id', 'condtn', 'wave', 'round',
       'position', 'positin1', 'order', 'partner', 'pid', 'field', 'field_cd', 'undergra',
       'mn_sat', 'tuition', 'career',
       'career_c', 'attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1',
       'shar1_1', 'attr4_1', 'sinc4_1', 'intel4_1', 'fun4_1', 'amb4_1',
       'shar4_1', 'attr2_1', 'sinc2_1', 'intel2_1', 'fun2_1', 'amb2_1',
       'shar2_1', 'attr3_1', 'sinc3_1', 'fun3_1', 'intel3_1', 'amb3_1',
       'attr5_1', 'sinc5_1', 'intel5_1', 'fun5_1', 'amb5_1', 'numdat_2', 'attr7_2', 'sinc7_2',
       'intel7_2', 'fun7_2', 'amb7_2', 'shar7_2', 'attr1_2', 'sinc1_2',
       'intel1_2', 'fun1_2', 'amb1_2', 'shar1_2', 'attr4_2', 'sinc4_2',
       'intel4_2', 'fun4_2', 'amb4_2', 'shar4_2', 'attr2_2', 'sinc2_2',
       'intel2_2', 'fun2_2', 'amb2_2', 'shar2_2', 'attr3_2', 'sinc3_2',
       'intel3_2', 'fun3_2', 'amb3_2', 'attr5_2', 'sinc5_2', 'intel5_2',
       'fun5_2', 'amb5_2', 'you_call', 'them_cal', 'date_3', 'numdat_3',
       'num_in_3', 'attr1_3', 'sinc1_3', 'intel1_3', 'fun1_3', 'amb1_3',
       'shar1_3', 'attr7_3', 'sinc7_3', 'intel7_3', 'fun7_3', 'amb7_3',
       'shar7_3', 'attr4_3', 'sinc4_3', 'intel4_3', 'fun4_3', 'amb4_3',
       'shar4_3', 'attr2_3', 'sinc2_3', 'intel2_3', 'fun2_3', 'amb2_3',
       'shar2_3', 'attr3_3', 'sinc3_3', 'intel3_3', 'fun3_3', 'amb3_3',
       'attr5_3', 'sinc5_3', 'intel5_3', 'fun5_3', 'amb5_3' ]).corr()
sns.heatmap(corr, vmin=-1, vmax=1, center=0, annot=False, cmap='RdBu')#, mask=matrix)

# %% [markdown]
# Personal decision and other person's decision most highly correlates with match which makes sense

# %%
rcParams['figure.figsize'] = 30,30

corr = df.drop(columns = ['iid', 'id', 'condtn', 'wave', 'round',
       'position', 'positin1', 'order', 'partner', 'pid', 'field', 'field_cd', 'undergra',
       'mn_sat', 'tuition', 'career',
       'career_c', 'dec', 'dec_o' ]).corr()
sns.heatmap(corr, vmin=-1, vmax=1, center=0, annot=False, cmap='RdBu')#, mask=matrix)

# %% [markdown]
# Match seems to be correlated ish to how people view their own attraction, intelligence, ambition, sincerity, fun, shared interest, and how there partner views those attributes

# %% [markdown]
# ##Data Visualization: Pairplot

# %%
#Choose some relevant features (attr_o, int_o, ...)
dftemp = df.drop(columns=['iid', 'id', 'gender', 'idg', 'condtn', 'wave', 'round',
       'position', 'positin1', 'order', 'partner', 'pid', 
       'int_corr', 'samerace', 'age_o', 'race_o', 'pf_o_att', 'pf_o_sin',
       'pf_o_int', 'pf_o_fun', 'pf_o_amb', 'pf_o_sha', 'dec_o', 'age', 'field', 'field_cd', 'undergra',
       'mn_sat', 'tuition', 'race', 'imprace', 'imprelig', 'from',
       'zipcode', 'income', 'goal', 'date', 'go_out', 'career',
       'career_c', 'sports', 'tvsports', 'exercise', 'dining', 'museums',
       'art', 'hiking', 'gaming', 'clubbing', 'reading', 'tv', 'theater',
       'movies', 'concerts', 'music', 'shopping', 'yoga', 'exphappy',
       'expnum', 'attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1',
       'shar1_1', 'attr4_1', 'sinc4_1', 'intel4_1', 'fun4_1', 'amb4_1',
       'shar4_1', 'attr2_1', 'sinc2_1', 'intel2_1', 'fun2_1', 'amb2_1',
       'shar2_1', 'attr3_1', 'sinc3_1', 'fun3_1', 'intel3_1', 'amb3_1',
       'attr5_1', 'sinc5_1', 'intel5_1', 'fun5_1', 'amb5_1', 'dec',
       'attr', 'sinc', 'intel', 'fun', 'amb', 'shar', 'like', 'prob',
       'met', 'match_es', 'attr1_s', 'sinc1_s', 'intel1_s', 'fun1_s',
       'amb1_s', 'shar1_s', 'attr3_s', 'sinc3_s', 'intel3_s', 'fun3_s',
       'amb3_s', 'satis_2', 'length', 'numdat_2', 'attr7_2', 'sinc7_2',
       'intel7_2', 'fun7_2', 'amb7_2', 'shar7_2', 'attr1_2', 'sinc1_2',
       'intel1_2', 'fun1_2', 'amb1_2', 'shar1_2', 'attr4_2', 'sinc4_2',
       'intel4_2', 'fun4_2', 'amb4_2', 'shar4_2', 'attr2_2', 'sinc2_2',
       'intel2_2', 'fun2_2', 'amb2_2', 'shar2_2', 'attr3_2', 'sinc3_2',
       'intel3_2', 'fun3_2', 'amb3_2', 'attr5_2', 'sinc5_2', 'intel5_2',
       'fun5_2', 'amb5_2', 'you_call', 'them_cal', 'date_3', 'numdat_3',
       'num_in_3', 'attr1_3', 'sinc1_3', 'intel1_3', 'fun1_3', 'amb1_3',
       'shar1_3', 'attr7_3', 'sinc7_3', 'intel7_3', 'fun7_3', 'amb7_3',
       'shar7_3', 'attr4_3', 'sinc4_3', 'intel4_3', 'fun4_3', 'amb4_3',
       'shar4_3', 'attr2_3', 'sinc2_3', 'intel2_3', 'fun2_3', 'amb2_3',
       'shar2_3', 'attr3_3', 'sinc3_3', 'intel3_3', 'fun3_3', 'amb3_3',
       'attr5_3', 'sinc5_3', 'intel5_3', 'fun5_3', 'amb5_3'])
sns.pairplot(dftemp, hue='match', diag_kind='kde')

# %%
#other relevant features (att, int, sin etc.)
dftemp = df.drop(columns=['iid', 'id', 'gender', 'idg', 'condtn', 'wave', 'round',
       'position', 'positin1', 'order', 'partner', 'pid', 
       'int_corr', 'samerace', 'age_o', 'race_o', 'pf_o_att', 'pf_o_sin',
       'pf_o_int', 'pf_o_fun', 'pf_o_amb', 'pf_o_sha', 'dec_o', 'attr_o',
       'sinc_o', 'intel_o', 'fun_o', 'amb_o', 'shar_o', 'like_o',
       'prob_o', 'met_o', 'age', 'field', 'field_cd', 'undergra',
       'mn_sat', 'tuition', 'race', 'imprace', 'imprelig', 'from',
       'zipcode', 'income', 'goal', 'date', 'go_out', 'career',
       'career_c', 'sports', 'tvsports', 'exercise', 'dining', 'museums',
       'art', 'hiking', 'gaming', 'clubbing', 'reading', 'tv', 'theater',
       'movies', 'concerts', 'music', 'shopping', 'yoga', 'exphappy',
       'expnum', 'attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1',
       'shar1_1', 'attr4_1', 'sinc4_1', 'intel4_1', 'fun4_1', 'amb4_1',
       'shar4_1', 'attr2_1', 'sinc2_1', 'intel2_1', 'fun2_1', 'amb2_1',
       'shar2_1', 'attr3_1', 'sinc3_1', 'fun3_1', 'intel3_1', 'amb3_1',
       'attr5_1', 'sinc5_1', 'intel5_1', 'fun5_1', 'amb5_1', 'dec',
       'match_es', 'attr1_s', 'sinc1_s', 'intel1_s', 'fun1_s',
       'amb1_s', 'shar1_s', 'attr3_s', 'sinc3_s', 'intel3_s', 'fun3_s',
       'amb3_s', 'satis_2', 'length', 'numdat_2', 'attr7_2', 'sinc7_2',
       'intel7_2', 'fun7_2', 'amb7_2', 'shar7_2', 'attr1_2', 'sinc1_2',
       'intel1_2', 'fun1_2', 'amb1_2', 'shar1_2', 'attr4_2', 'sinc4_2',
       'intel4_2', 'fun4_2', 'amb4_2', 'shar4_2', 'attr2_2', 'sinc2_2',
       'intel2_2', 'fun2_2', 'amb2_2', 'shar2_2', 'attr3_2', 'sinc3_2',
       'intel3_2', 'fun3_2', 'amb3_2', 'attr5_2', 'sinc5_2', 'intel5_2',
       'fun5_2', 'amb5_2', 'you_call', 'them_cal', 'date_3', 'numdat_3',
       'num_in_3', 'attr1_3', 'sinc1_3', 'intel1_3', 'fun1_3', 'amb1_3',
       'shar1_3', 'attr7_3', 'sinc7_3', 'intel7_3', 'fun7_3', 'amb7_3',
       'shar7_3', 'attr4_3', 'sinc4_3', 'intel4_3', 'fun4_3', 'amb4_3',
       'shar4_3', 'attr2_3', 'sinc2_3', 'intel2_3', 'fun2_3', 'amb2_3',
       'shar2_3', 'attr3_3', 'sinc3_3', 'intel3_3', 'fun3_3', 'amb3_3',
       'attr5_3', 'sinc5_3', 'intel5_3', 'fun5_3', 'amb5_3'])
sns.pairplot(dftemp, hue='match', diag_kind='kde')

# %% [markdown]
# ####Preprocessing Needs
# - normalization will be required since some of the data is not normal and quite a few features have different ranges
# - dropping columns will have to be carried out to extract what we need to test our hypotheses
